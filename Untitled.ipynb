# %% [markdown]
# # Time series analysis of S&P

# %%
import numpy as np
import pandas as pd
import os

data_location = 'Data/^GSPC.csv'
data = pd.read_csv(data_location, index_col=0)
data
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 1995-01-01   459.209991   471.359985   457.200012   470.420013   470.420013
# 1995-02-01   470.420013   489.190002   469.290009   487.390015   487.390015
# 1995-03-01   487.390015   508.149994   479.700012   500.709991   500.709991
# 1995-04-01   500.700012   515.289978   500.200012   514.710022   514.710022
# 1995-05-01   514.760010   533.409973   513.030029   533.400024   533.400024
# 1995-06-01   533.400024   551.070007   526.000000   544.750000   544.750000
# 1995-07-01   544.750000   565.400024   542.510010   562.059998   562.059998
# 1995-08-01   562.059998   565.619995   553.039978   561.880005   561.880005
# 1995-09-01   561.880005   587.609985   561.010010   584.409973   584.409973
# 1995-10-01   584.409973   590.659973   571.549988   581.500000   581.500000
# 1995-11-01   581.500000   608.690002   581.039978   605.369995   605.369995
# ...

# %%
data.index = data.index.astype('datetime64[ns]')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plot = data['Adj Close'].plot(x='Date', use_index=True)
# plot.set_xticklabels(data['Adj Close'].index)

# %% [markdown]
# ## Split 2015 as test set

# %%
test = data[data.index.year==2015]
train = data[data.index.year!=2015]

# %%
import statsmodels
